# %% [markdown]
# <a href="https://colab.research.google.com/github/epvillanueva10/Datos/blob/main/P1_ImagePreprocessing_Py6S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Atmospheric correction of Sentinel 2 image using Py6S in Google Colab environment**
#
#
# Guidance and reference provided at the following websites are appreciated.
#
# *   https://github.com/samsammurphy/gee-atmcorr-S2
# *   https://github.com/ndminhhus/geeguide/blob/master/02.Atm-correction.md
# *   https://blog.csdn.net/qq_45110581/article/details/108629636
# *   https://github.com/ivanhykwong/marine-water-quality-time-series-hk

# %% [markdown]
# # Step 1 - Set up Py6S in Google Colab

# %%
# !gfortran -v
# !wget http://rtwilson.com/downloads/6SV-1.1.tar
# !tar xvf 6SV-1.1.tar
# !cd 6SV1.1
# Out:
# Using built-in specs.
# COLLECT_GCC=gfortran
# COLLECT_LTO_WRAPPER=/usr/lib/gcc/x86_64-linux-gnu/11/lto-wrapper
# OFFLOAD_TARGET_NAMES=nvptx-none:amdgcn-amdhsa
# OFFLOAD_TARGET_DEFAULT=1
# Target: x86_64-linux-gnu
# Configured with: ../src/configure -v --with-pkgversion='Ubuntu 11.4.0-1ubuntu1~22.04' --with-bugurl=file:///usr/share/doc/gcc-11/README.Bugs --enable-languages=c,ada,c++,go,brig,d,fortran,objc,obj-c++,m2 --prefix=/usr --with-gcc-major-version-only --program-suffix=-11 --program-prefix=x86_64-linux-gnu- --enable-shared --enable-linker-build-id --libexecdir=/usr/lib --without-included-gettext --enable-threads=posix --libdir=/usr/lib --enable-nls --enable-bootstrap --enable-clocale=gnu --enable-libstdcxx-debug --enable-libstdcxx-time=yes --with-default-libstdcxx-abi=new --enable-gnu-unique-object --disable-vtable-verify --enable-plugin --enable-default-pie --with-system-zlib --enable-libphobos-checking=release --with-target-system-zlib=auto --enable-objc-gc=auto --enable-multiarch --disable-werror --enable-cet --with-arch-32=i686 --with-abi=m64 --with-multilib-list=m32,m64,mx32 --enable-multilib --with-tune=generic --enable-offload-targets=nvptx-none=/build/gcc-11-XeT9lY/gcc-11-11.4.0/debian/tmp-nvptx/usr,amdgcn-amdhsa=/build/gcc-11-XeT9lY/gcc-11-11.4.0/debian/tmp-gcn/usr --without-cuda-driver --enable-checking=release --build=x86_64-linux-gnu --host=x86_64-linux-gnu --target=x86_64-linux-gnu --with-build-config=bootstrap-lto-lean --enable-link-serialization=2
# Thread model: posix
# Supported LTO compression algorithms: zlib zstd
# gcc version 11.4.0 (Ubuntu 11.4.0-1ubuntu1~22.04)
# --2024-02-13 19:16:25--  http://rtwilson.com/downloads/6SV-1.1.tar
# Resolving rtwilson.com (rtwilson.com)... 173.236.139.165
# Connecting to rtwilson.com (rtwilson.com)|173.236.139.165|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4075520 (3.9M) [application/x-tar]
# Saving to: ‘6SV-1.1.tar.5’
#
# 6SV-1.1.tar.5       100%[===================>]   3.89M  19.4MB/s    in 0.2s
#
# 2024-02-13 19:16:25 (19.4 MB/s) - ‘6SV-1.1.tar.5’ saved [4075520/4075520]
#
# 6SV1.1/
# 6SV1.1/AATSR.f
# 6SV1.1/ABSTRA.f
# 6SV1.1/AEROPROF.f
# 6SV1.1/AEROSO.f
# 6SV1.1/AKTOOL.f
# 6SV1.1/ATMREF.f
# 6SV1.1/AVHRR.f
# 6SV1.1/BBM.f
# 6SV1.1/BDM.f
# 6SV1.1/BRDFGRID.f
# 6SV1.1/CHAND.f
# 6SV1.1/CLEARW.f
# 6SV1.1/CSALBR.f
# 6SV1.1/DICA1.f
# 6SV1.1/DICA2.f
# 6SV1.1/DICA3.f
# 6SV1.1/DISCOM.f
# 6SV1.1/DISCRE.f
# 6SV1.1/DUST.f
# 6SV1.1/ENVIRO.f
# 6SV1.1/EQUIVWL.f
# 6SV1.1/GAUSS.f
# 6SV1.1/GLI.f
# 6SV1.1/GOES.f
# 6SV1.1/HAPKALBE.f
# 6SV1.1/HAPKBRDF.f
# 6SV1.1/HRV.f
# 6SV1.1/IAPIALBE.f
# 6SV1.1/IAPIBRDF.f
# 6SV1.1/IAPITOOLS.f
# 6SV1.1/INTERP.f
# 6SV1.1/ISO.f
# 6SV1.1/KERNEL.f
# 6SV1.1/KERNELPOL.f
# 6SV1.1/LAKEW.f
# 6SV1.1/main.f
# 6SV1.1/MAS.f
# 6SV1.1/MERIS.f
# 6SV1.1/METEO.f
# 6SV1.1/METH1.f
# 6SV1.1/METH2.f
# 6SV1.1/METH3.f
# 6SV1.1/METH4.f
# 6SV1.1/METH5.f
# 6SV1.1/METH6.f
# 6SV1.1/MIDSUM.f
# 6SV1.1/MIDWIN.f
# 6SV1.1/MIE.f
# 6SV1.1/MINNALBE.f
# 6SV1.1/MINNBRDF.f
# 6SV1.1/MOCA1.f
# 6SV1.1/MOCA2.f
# 6SV1.1/MOCA3.f
# 6SV1.1/MOCA4.f
# 6SV1.1/MOCA5.f
# 6SV1.1/MOCA6.f
# 6SV1.1/MODISALBE.f
# 6SV1.1/MODISBRDF.f
# 6SV1.1/MODIS.f
# 6SV1.1/MSS.f
# 6SV1.1/NIOX1.f
# 6SV1.1/NIOX2.f
# 6SV1.1/NIOX3.f
# 6SV1.1/NIOX4.f
# 6SV1.1/NIOX5.f
# 6SV1.1/NIOX6.f
# 6SV1.1/OCEAALBE.f
# 6SV1.1/OCEABRDF.f
# 6SV1.1/OCEABRDFFAST.f
# 6SV1.1/OCEA.f
# 6SV1.1/OCEATOOLS.f
# 6SV1.1/ODA550.f
# 6SV1.1/ODRAYL.f
# 6SV1.1/OS.f
# 6SV1.1/OSPOL.f
# 6SV1.1/OXYG3.f
# 6SV1.1/OXYG4.f
# 6SV1.1/OXYG5.f
# 6SV1.1/OXYG6.f
# 6SV1.1/OZON1.f
# 6SV1.1/PLANPOL.f
# 6SV1.1/POLDER.f
# 6SV1.1/POLGLIT.f
# 6SV1.1/POLNAD.f
# 6SV1.1/POSGE.f
# 6SV1.1/POSGW.f
# 6SV1.1/POSLAN.f
# 6SV1.1/POSMTO.f
# 6SV1.1/POSNOA.f
# 6SV1.1/POSSOL.f
# 6SV1.1/POSSPO.f
# 6SV1.1/PRESPLANE.f
# 6SV1.1/PRESSURE.f
# 6SV1.1/PRINT_ERROR.f
# 6SV1.1/RAHMALBE.f
# 6SV1.1/RAHMBRDF.f
# 6SV1.1/ROUJALBE.f
# 6SV1.1/ROUJBRDF.f
# 6SV1.1/SAND.f
# 6SV1.1/SCATRA.f
# 6SV1.1/SEAWIFS.f
# 6SV1.1/SOLIRR.f
# 6SV1.1/SOOT.f
# 6SV1.1/SPECINTERP.f
# 6SV1.1/SPLIE2.f
# 6SV1.1/SPLIN2.f
# 6SV1.1/SPLINE.f
# 6SV1.1/SPLINT.f
# 6SV1.1/STM.f
# 6SV1.1/SUBSUM.f
# 6SV1.1/SUBWIN.f
# 6SV1.1/TM.f
# 6SV1.1/TROPIC.f
# 6SV1.1/TRUNCA.f
# 6SV1.1/US62.f
# 6SV1.1/VARSOL.f
# 6SV1.1/VEGETA.f
# 6SV1.1/VERSALBE.f
# 6SV1.1/VERSBRDF.f
# 6SV1.1/VERSTOOLS.f
# 6SV1.1/WALTALBE.f
# 6SV1.1/WALTBRDF.f
# 6SV1.1/WATE.f
# 6SV1.1/WAVA1.f
# 6SV1.1/WAVA2.f
# 6SV1.1/WAVA3.f
# 6SV1.1/WAVA4.f
# 6SV1.1/WAVA5.f
# 6SV1.1/WAVA6.f
# 6SV1.1/Makefile
# 6SV1.1/paramdef.inc
# 6SV1.1/sixsV1.1
# 6SV1.1/ASTER.f
# 6SV1.1/ALI.f
# 6SV1.1/ETM.f
# 6SV1.1/HYPBLUE.f
# 6SV1.1/VIIRS.f
# 6SV1.1/VGT.f
# Examples/
# Examples/Example_In_3.txt
# Examples/Example_Out_3.txt
# Examples/Example_In_1.txt
# Examples/Example_Out_1.txt
# Examples/Example_In_2.txt
# Examples/Example_Out_2.txt
# Examples/Example_In_4.txt
# Examples/Example_Out_4.txt

# %% [markdown]
# **Manual work required before executing the subsequent code**
#
# Refer to comments below

# %%
# modify "makefile" from "FC = g77 $(FFLAGS)" to "FC = gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none $(FFLAGS)"
# upload modified "makefile" to /content/6SV1.1

import os
os.chdir("/content/6SV1.1")
# !ls
# !make
os.environ["PATH"]="/content/6SV1.1:"+os.environ["PATH"]
# test
# !sixsV1.1 < /content/Examples/Example_In_1.txt
# !pip install Py6S
from Py6S import *
SixS.test()
# Out:
# 6SV1.1	       CSALBR.f     INTERP.f	 MOCA1.f	 ODA550.f      PRESPLANE.f    TM.f
# 6SV-1.1.tar    DICA1.f	    ISO.f	 MOCA2.f	 ODRAYL.f      PRESSURE.f     TROPIC.f
# 6SV-1.1.tar.1  DICA2.f	    KERNEL.f	 MOCA3.f	 OS.f	       PRINT_ERROR.f  TRUNCA.f
# 6SV-1.1.tar.2  DICA3.f	    KERNELPOL.f  MOCA4.f	 OSPOL.f       RAHMALBE.f     US62.f
# 6SV-1.1.tar.3  DISCOM.f     LAKEW.f	 MOCA5.f	 OXYG3.f       RAHMBRDF.f     VARSOL.f
# 6SV-1.1.tar.4  DISCRE.f     main.f	 MOCA6.f	 OXYG4.f       ROUJALBE.f     VEGETA.f
# 6SV-1.1.tar.5  DUST.f	    Makefile	 MODISALBE.f	 OXYG5.f       ROUJBRDF.f     VERSALBE.f
# AATSR.f        ENVIRO.f     MAS.f	 MODISBRDF.f	 OXYG6.f       SAND.f	      VERSBRDF.f
# ABSTRA.f       EQUIVWL.f    MERIS.f	 MODIS.f	 OZON1.f       SCATRA.f       VERSTOOLS.f
# AEROPROF.f     ETM.f	    METEO.f	 MSS.f		 paramdef.inc  SEAWIFS.f      VGT.f
# AEROSO.f       Examples     METH1.f	 NIOX1.f	 PLANPOL.f     sixsV1.1       VIIRS.f
# AKTOOL.f       GAUSS.f	    METH2.f	 NIOX2.f	 POLDER.f      SOLIRR.f       WALTALBE.f
# ALI.f	       GLI.f	    METH3.f	 NIOX3.f	 POLGLIT.f     SOOT.f	      WALTBRDF.f
# ASTER.f        GOES.f	    METH4.f	 NIOX4.f	 POLNAD.f      SPECINTERP.f   WATE.f
# ATMREF.f       HAPKALBE.f   METH5.f	 NIOX5.f	 POSGE.f       SPLIE2.f       WAVA1.f
# AVHRR.f        HAPKBRDF.f   METH6.f	 NIOX6.f	 POSGW.f       SPLIN2.f       WAVA2.f
# BBM.f	       HRV.f	    MIDSUM.f	 OCEAALBE.f	 POSLAN.f      SPLINE.f       WAVA3.f
# BDM.f	       HYPBLUE.f    MIDWIN.f	 OCEABRDF.f	 POSMTO.f      SPLINT.f       WAVA4.f
# BRDFGRID.f     IAPIALBE.f   MIE.f	 OCEABRDFFAST.f  POSNOA.f      STM.f	      WAVA5.f
# CHAND.f        IAPIBRDF.f   MINNALBE.f	 OCEA.f		 POSSOL.f      SUBSUM.f       WAVA6.f
# CLEARW.f       IAPITOOLS.f  MINNBRDF.f	 OCEATOOLS.f	 POSSPO.f      SUBWIN.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o AATSR.o AATSR.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o ABSTRA.o ABSTRA.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o AEROSO.o AEROSO.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o AKTOOL.o AKTOOL.f
# AKTOOL.f:1570:16:
#
#  1570 |       call dakg(uu, aa, n)
#       |                1
# Warning: Actual argument contains too few elements for dummy argument ‘u’ (20/48) at (1)
# AKTOOL.f:1579:16:
#
#  1579 |       call dakg(uu, aa, n)
#       |                1
# Warning: Actual argument contains too few elements for dummy argument ‘u’ (20/48) at (1)
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o ATMREF.o ATMREF.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o AVHRR.o AVHRR.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o BBM.o BBM.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o BDM.o BDM.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o BRDFGRID.o BRDFGRID.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o CHAND.o CHAND.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o CLEARW.o CLEARW.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o CSALBR.o CSALBR.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o DICA1.o DICA1.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o DICA2.o DICA2.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o DICA3.o DICA3.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o DISCOM.o DISCOM.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o DISCRE.o DISCRE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o DUST.o DUST.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o ENVIRO.o ENVIRO.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o EQUIVWL.o EQUIVWL.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o GAUSS.o GAUSS.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o GLI.o GLI.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o GOES.o GOES.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o HAPKALBE.o HAPKALBE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o HAPKBRDF.o HAPKBRDF.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o HRV.o HRV.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o IAPIALBE.o IAPIALBE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o IAPIBRDF.o IAPIBRDF.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o IAPITOOLS.o IAPITOOLS.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o INTERP.o INTERP.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o ISO.o ISO.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o KERNEL.o KERNEL.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o KERNELPOL.o KERNELPOL.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o LAKEW.o LAKEW.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MAS.o MAS.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MERIS.o MERIS.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o METEO.o METEO.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o METH1.o METH1.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o METH2.o METH2.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o METH3.o METH3.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o METH4.o METH4.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o METH5.o METH5.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o METH6.o METH6.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MIDSUM.o MIDSUM.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MIDWIN.o MIDWIN.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MIE.o MIE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MINNALBE.o MINNALBE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MINNBRDF.o MINNBRDF.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MOCA1.o MOCA1.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MOCA2.o MOCA2.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MOCA3.o MOCA3.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MOCA4.o MOCA4.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MOCA5.o MOCA5.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MOCA6.o MOCA6.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MODIS.o MODIS.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MSS.o MSS.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o NIOX1.o NIOX1.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MODISBRDF.o MODISBRDF.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o MODISALBE.o MODISALBE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o NIOX2.o NIOX2.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o NIOX3.o NIOX3.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o NIOX4.o NIOX4.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o NIOX5.o NIOX5.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o NIOX6.o NIOX6.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o OCEA.o OCEA.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o OCEAALBE.o OCEAALBE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o OCEABRDF.o OCEABRDF.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o OCEABRDFFAST.o OCEABRDFFAST.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o OCEATOOLS.o OCEATOOLS.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o ODA550.o ODA550.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o ODRAYL.o ODRAYL.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o OS.o OS.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o OSPOL.o OSPOL.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o OXYG3.o OXYG3.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o OXYG4.o OXYG4.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o OXYG5.o OXYG5.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o OXYG6.o OXYG6.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o OZON1.o OZON1.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o PLANPOL.o PLANPOL.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o POLDER.o POLDER.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o POSGE.o POSGE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o POSGW.o POSGW.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o POSLAN.o POSLAN.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o POSMTO.o POSMTO.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o POSNOA.o POSNOA.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o POSSOL.o POSSOL.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o POSSPO.o POSSPO.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o POLGLIT.o POLGLIT.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o POLNAD.o POLNAD.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o PRESPLANE.o PRESPLANE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o PRESSURE.o PRESSURE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o PRINT_ERROR.o PRINT_ERROR.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o RAHMALBE.o RAHMALBE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o RAHMBRDF.o RAHMBRDF.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o ROUJALBE.o ROUJALBE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o ROUJBRDF.o ROUJBRDF.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o SAND.o SAND.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o SCATRA.o SCATRA.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o SEAWIFS.o SEAWIFS.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o SOLIRR.o SOLIRR.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o SOOT.o SOOT.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o SPECINTERP.o SPECINTERP.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o SPLIE2.o SPLIE2.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o SPLIN2.o SPLIN2.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o SPLINE.o SPLINE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o SPLINT.o SPLINT.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o STM.o STM.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o SUBSUM.o SUBSUM.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o SUBWIN.o SUBWIN.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o TM.o TM.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o TROPIC.o TROPIC.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o TRUNCA.o TRUNCA.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o US62.o US62.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o VARSOL.o VARSOL.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o VEGETA.o VEGETA.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o VERSALBE.o VERSALBE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o VERSBRDF.o VERSBRDF.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o VERSTOOLS.o VERSTOOLS.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o WALTALBE.o WALTALBE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o WALTBRDF.o WALTBRDF.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o WATE.o WATE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o WAVA1.o WAVA1.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o WAVA2.o WAVA2.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o WAVA3.o WAVA3.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o WAVA4.o WAVA4.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o WAVA5.o WAVA5.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o WAVA6.o WAVA6.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o AEROPROF.o AEROPROF.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o ALI.o ALI.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o ASTER.o ASTER.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o ETM.o ETM.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o HYPBLUE.o HYPBLUE.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o VGT.o VGT.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o VIIRS.o VIIRS.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O -O  -c -o main.o main.f
# gfortran -std=legacy -ffixed-line-length-none -ffpe-summary=none -O  main.o  AATSR.o ABSTRA.o AEROSO.o AKTOOL.o ATMREF.o AVHRR.o BBM.o BDM.o BRDFGRID.o CHAND.o CLEARW.o CSALBR.o DICA1.o DICA2.o DICA3.o  DISCOM.o DISCRE.o DUST.o ENVIRO.o EQUIVWL.o GAUSS.o GLI.o GOES.o HAPKALBE.o HAPKBRDF.o HRV.o IAPIALBE.o IAPIBRDF.o IAPITOOLS.o INTERP.o ISO.o KERNEL.o KERNELPOL.o LAKEW.o MAS.o MERIS.o METEO.o METH1.o METH2.o METH3.o METH4.o METH5.o METH6.o MIDSUM.o MIDWIN.o MIE.o MINNALBE.o MINNBRDF.o MOCA1.o MOCA2.o MOCA3.o MOCA4.o MOCA5.o MOCA6.o MODIS.o MSS.o NIOX1.o MODISBRDF.o MODISALBE.o NIOX2.o NIOX3.o NIOX4.o NIOX5.o NIOX6.o OCEA.o OCEAALBE.o OCEABRDF.o OCEABRDFFAST.o OCEATOOLS.o ODA550.o ODRAYL.o OS.o OSPOL.o OXYG3.o OXYG4.o OXYG5.o OXYG6.o OZON1.o PLANPOL.o POLDER.o POSGE.o POSGW.o POSLAN.o POSMTO.o POSNOA.o POSSOL.o POSSPO.o POLGLIT.o POLNAD.o PRESPLANE.o PRESSURE.o PRINT_ERROR.o RAHMALBE.o RAHMBRDF.o ROUJALBE.o ROUJBRDF.o SAND.o SCATRA.o SEAWIFS.o SOLIRR.o SOOT.o SPECINTERP.o SPLIE2.o SPLIN2.o SPLINE.o SPLINT.o STM.o SUBSUM.o SUBWIN.o TM.o TROPIC.o TRUNCA.o US62.o VARSOL.o VEGETA.o VERSALBE.o VERSBRDF.o VERSTOOLS.o WALTALBE.o WALTBRDF.o WATE.o WAVA1.o WAVA2.o WAVA3.o WAVA4.o WAVA5.o WAVA6.o AEROPROF.o ALI.o ASTER.o ETM.o HYPBLUE.o VGT.o VIIRS.o -o sixsV1.1  -lm
#
#
#
#
#
# ******************************* 6SV version 1.1 *******************************
# *                                                                             *
# *                       geometrical conditions identity                       *
# *                       -------------------------------                       *
# *                       user defined conditions                               *
# *                                                                             *
# *   month:  7 day :  23                                                       *
# *   solar zenith angle:   40.00 deg  solar azimuthal angle:      100.00 deg   *
# *   view zenith angle:    45.00 deg  view azimuthal angle:        50.00 deg   *
# *   scattering angle:    146.49 deg  azimuthal angle difference:  50.00 deg   *
# *                                                                             *
# *                       atmospheric model description                         *
# *                       -----------------------------                         *
# *           atmospheric model identity :                                      *
# *             user defined water content : uh2o= 3.000 g/cm2                  *
# *             user defined ozone content : uo3 = 3.500 cm-atm                 *
# *           aerosols type identity :                                          *
# *             user-defined aerosol model:                                     *
# *                           0.250 % of dust-like                              *
# *                           0.250 % of water-soluble                          *
# *                           0.250 % of oceanic                                *
# *                           0.250 % of soot                                   *
# *           optical condition identity :                                      *
# *               visibility :  8.49 km  opt. thick. 550 nm :  0.5000           *
# *                                                                             *
# *                       spectral condition                                    *
# *                       ------------------                                    *
# *           avhrr 1 (noaa9)                                                   *
# *               value of filter function :                                    *
# *                wl inf= 0.530 mic   wl sup= 0.810 mic                        *
# *                                                                             *
# *                       Surface polarization parameters                       *
# *                       ----------------------------------                    *
# *                                                                             *
# *                                                                             *
# * Surface Polarization Q,U,Rop,Chi    0.00000  0.00000  0.00000     0.00      *
# *                                                                             *
# *                                                                             *
# *                       target type                                           *
# *                       -----------                                           *
# *           inhomogeneous ground , radius of target  0.500 km                 *
# *                target reflectance :                                         *
# *             spectral clear water reflectance       0.045                    *
# *                environmental reflectance :                                  *
# *             spectral vegetation ground reflectance 0.129                    *
# *                                                                             *
# *                       target elevation description                          *
# *                       ----------------------------                          *
# *           ground pressure  [mb]  989.01                                     *
# *           ground altitude  [km] 0.200                                       *
# *                gaseous content at target level:                             *
# *                uh2o= 3.000 g/cm2        uo3= 3.500 cm-atm                   *
# *                                                                             *
# *                       plane simulation description                          *
# *                       ----------------------------                          *
# *           plane  pressure          [mb]  657.54                             *
# *           plane  altitude absolute [km]  3.500                              *
# *                atmosphere under plane description:                          *
# *                ozone content             0.082                              *
# *                h2o   content             2.389                              *
# *               aerosol opt. thick. 550nm  0.281                              *
# *                                                                             *
# *                        atmospheric correction activated                     *
# *                        --------------------------------                     *
# *                        BRDF coupling correction                             *
# *           input apparent reflectance :  0.100                               *
# *                                                                             *
# *******************************************************************************
#
#
#
# *******************************************************************************
# *                                                                             *
# *                         integrated values of  :                             *
# *                         --------------------                                *
# *                                                                             *
# *       apparent reflectance  0.0330896  appar. rad.(w/m2/sr/mic)   12.749    *
# *                   total gaseous transmittance  0.675                        *
# *                                                                             *
# *******************************************************************************
# *                                                                             *
# *                         coupling aerosol -wv  :                             *
# *                         --------------------                                *
# *           wv above aerosol :   0.033     wv mixed with aerosol :   0.033    *
# *                       wv under aerosol :   0.033                            *
# *******************************************************************************
# *                                                                             *
# *                         integrated values of  :                             *
# *                         --------------------                                *
# *                                                                             *
# *       app. polarized refl.  0.0014    app. pol. rad. (w/m2/sr/mic)    0.065 *
# *             direction of the plane of polarization-27.40                    *
# *                   total polarization ratio     0.043                        *
# *                                                                             *
# *******************************************************************************
# *                                                                             *
# *                         int. normalized  values  of  :                      *
# *                         ---------------------------                         *
# *                      % of irradiance at ground level                        *
# *     % of direct  irr.    % of diffuse irr.    % of enviro. irr              *
# *               0.773               0.221               0.005                 *
# *                       reflectance at satellite level                        *
# *     atm. intrin. ref.   environment ref.  target reflectance                *
# *               0.015               0.004               0.014                 *
# *                                                                             *
# *                         int. absolute values of                             *
# *                         -----------------------                             *
# *                      irr. at ground level (w/m2/mic)                        *
# *     direct solar irr.    atm. diffuse irr.    environment  irr              *
# *             453.574             127.136               3.157                 *
# *                      rad at satel. level (w/m2/sr/mic)                      *
# *     atm. intrin. rad.    environment rad.    target radiance                *
# *               5.649               1.633               5.468                 *
# *                                                                             *
# *                                                                             *
# *          int. funct filter (in mic)              int. sol. spect (in w/m2)  *
# *             0.1174545                                 185.589               *
# *                                                                             *
# *******************************************************************************
#
#
#
#
#
# *******************************************************************************
# *                                                                             *
# *                          integrated values of  :                            *
# *                          --------------------                               *
# *                                                                             *
# *                             downward        upward          total           *
# *      global gas. trans. :     0.68965        0.97248        0.67513         *
# *      water   "     "    :     0.98573        0.98623        0.97592         *
# *      ozone   "     "    :     0.70609        0.99079        0.70008         *
# *      co2     "     "    :     1.00000        1.00000        1.00000         *
# *      oxyg    "     "    :     0.99344        0.99533        0.99179         *
# *      no2     "     "    :     1.00000        1.00000        1.00000         *
# *      ch4     "     "    :     1.00000        1.00000        1.00000         *
# *      co      "     "    :     1.00000        1.00000        1.00000         *
# *                                                                             *
# *                                                                             *
# *      rayl.  sca. trans. :     0.96494        0.93809        0.90520         *
# *      aeros. sca.   "    :     0.72090        0.82111        0.59194         *
# *      total  sca.   "    :     0.69208        0.81074        0.56110         *
# *                                                                             *
# *                                                                             *
# *                                                                             *
# *                             rayleigh       aerosols         total           *
# *                                                                             *
# *      spherical albedo   :     0.04939        0.04918        0.06820         *
# *      optical depth total:     0.05550        0.42021        0.47570         *
# *      optical depth plane:     0.01848        0.23606        0.25454         *
# *      reflectance I      :     0.01098        0.01327        0.02175         *
# *      reflectance Q      :     0.00118        0.00037        0.00122         *
# *      reflectance U      :    -0.00156        0.00000       -0.00173         *
# *      polarized reflect. :     0.00195        0.00037        0.00212         *
# *      degree of polar.   :       17.77           2.76           9.75         *
# *      dir. plane polar.  :      -26.48           0.00         -27.43         *
# *      phase function I   :     1.26026        0.27565        0.39051         *
# *      phase function Q   :    -0.21911       -0.00611       -0.03096         *
# *      phase function U   :    -1.19913       -0.15957       -0.28084         *
# *      primary deg. of pol:    -0.17386       -0.02215       -0.07927         *
# *      sing. scat. albedo :     1.00000        0.52284        0.57850         *
# *                                                                             *
# *                                                                             *
# *******************************************************************************
# *******************************************************************************
#
#
#
# *******************************************************************************
# *                        atmospheric correction result                        *
# *                        -----------------------------                        *
# *       input apparent reflectance            :    0.100                      *
# *       measured radiance [w/m2/sr/mic]       :   38.529                      *
# *       atmospherically corrected reflectance                                 *
# *       Lambertian case :      0.22187                                        *
# *       BRDF       case :      0.22187                                        *
# *       coefficients xa xb xc                 :  0.00685  0.03870  0.06820    *
# *       y=xa*(measured radiance)-xb;  acr=y/(1.+xc*y)                         *
# *******************************************************************************
# Requirement already satisfied: Py6S in /usr/local/lib/python3.10/dist-packages (1.9.2)
# Requirement already satisfied: pysolar>=0.9 in /usr/local/lib/python3.10/dist-packages (from Py6S) (0.11)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from Py6S) (1.11.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pysolar>=0.9->Py6S) (1.25.2)
# 6S wrapper script by Robin Wilson
# Using 6S located at /content/6SV1.1/sixsV1.1
# Running 6S using a set of test parameters
# 6sV version: 1.1
# The results are:
# Expected result: 619.158000
# Actual result: 619.158000
# #### Results agree, Py6S is working correctly
# 0

# %% [markdown]
# # Step 2 - Define functions required in atmospheric correction

# %% [markdown]
# **Functions created by Sam Murphy**
#
#
# *   https://github.com/samsammurphy/gee-atmcorr-S2

# %%
"""
atmospheric.py, Sam Murphy (2016-10-26)
Atmospheric water vapour, ozone and AOT from GEE
Usage
H2O = Atmospheric.water(geom,date)
O3 = Atmospheric.ozone(geom,date)
AOT = Atmospheric.aerosol(geom,date)
"""
class Atmospheric():

  def round_date(date,xhour):
    """
    rounds a date of to the closest 'x' hours
    """
    y = date.get('year')
    m = date.get('month')
    d = date.get('day')
    H = date.get('hour')
    HH = H.divide(xhour).round().multiply(xhour)
    return date.fromYMD(y,m,d).advance(HH,'hour')

  def round_month(date):
    """
    round date to closest month
    """
    # start of THIS month
    m1 = date.fromYMD(date.get('year'),date.get('month'),ee.Number(1))
    # start of NEXT month
    m2 = m1.advance(1,'month')
    # difference from date
    d1 = ee.Number(date.difference(m1,'day')).abs()
    d2 = ee.Number(date.difference(m2,'day')).abs()
    # return closest start of month
    return ee.Date(ee.Algorithms.If(d2.gt(d1),m1,m2))

  def water(geom,date):
    """
    Water vapour column above target at time of image aquisition.
    (Kalnay et al., 1996, The NCEP/NCAR 40-Year Reanalysis Project. Bull.
    Amer. Meteor. Soc., 77, 437-471)

    """
    # Point geometry required
    centroid = geom.centroid()
    # H2O datetime is in 6 hour intervals
    H2O_date = Atmospheric.round_date(date,6)
    # filtered water collection
    water_ic = ee.ImageCollection('NCEP_RE/surface_wv').filterDate(H2O_date, H2O_date.advance(1,'month'))
    # water image
    water_img = ee.Image(water_ic.first())
    # water_vapour at target
    water = water_img.reduceRegion(reducer=ee.Reducer.mean(), geometry=centroid).get('pr_wtr')
    # convert to Py6S units (Google = kg/m^2, Py6S = g/cm^2)
    water_Py6S_units = ee.Number(water).divide(10)
    return water_Py6S_units

  def ozone(geom,date):
    """
    returns ozone measurement from merged TOMS/OMI dataset
    OR
    uses our fill value (which is mean value for that latlon and day-of-year)
    """
    # Point geometry required
    centroid = geom.centroid()

    def ozone_measurement(centroid,O3_date):
      # filtered ozone collection
      ozone_ic = ee.ImageCollection('TOMS/MERGED').filterDate(O3_date, O3_date.advance(1,'month'))
      # ozone image
      ozone_img = ee.Image(ozone_ic.first())
      # ozone value IF TOMS/OMI image exists ELSE use fill value
      ozone = ee.Algorithms.If(ozone_img,\
      ozone_img.reduceRegion(reducer=ee.Reducer.mean(), geometry=centroid).get('ozone'),\
      ozone_fill(centroid,O3_date))
      return ozone

    def ozone_fill(centroid,O3_date):
      """
      Gets our ozone fill value (i.e. mean value for that doy and latlon) you can see it
      1) compared to LEDAPS: https://code.earthengine.google.com/8e62a5a66e4920e701813e43c0ecb83e
      2) as a video: https://www.youtube.com/watch?v=rgqwvMRVguI&feature=youtu.be
      """
      # ozone fills (i.e. one band per doy)
      ozone_fills = ee.ImageCollection('users/samsammurphy/public/ozone_fill').toList(366)
      # day of year index
      jan01 = ee.Date.fromYMD(O3_date.get('year'),1,1)
      doy_index = date.difference(jan01,'day').toInt()# (NB. index is one less than doy, so no need to +1)
      # day of year image
      fill_image = ee.Image(ozone_fills.get(doy_index))
      # return scalar fill value
      return fill_image.reduceRegion(reducer=ee.Reducer.mean(), geometry=centroid).get('ozone')

    # O3 datetime in 24 hour intervals
    O3_date = Atmospheric.round_date(date,24)
    # TOMS temporal gap
    TOMS_gap = ee.DateRange('1994-11-01','1996-08-01')
    # avoid TOMS gap entirely
    ozone = ee.Algorithms.If(TOMS_gap.contains(O3_date),ozone_fill(centroid,O3_date),ozone_measurement(centroid,O3_date))
    # fix other data gaps (e.g. spatial, missing images, etc..)
    ozone = ee.Algorithms.If(ozone,ozone,ozone_fill(centroid,O3_date))
    #convert to Py6S units
    ozone_Py6S_units = ee.Number(ozone).divide(1000)# (i.e. Dobson units are milli-atm-cm )
    return ozone_Py6S_units


  def aerosol(geom,date):
    """
    Aerosol Optical Thickness.
    try:
      MODIS Aerosol Product (monthly)
    except:
      fill value
    """
    def aerosol_fill(date):
      """
      MODIS AOT fill value for this month (i.e. no data gaps)
      """
      return ee.Image('users/samsammurphy/public/AOT_stack')\
               .select([ee.String('AOT_').cat(date.format('M'))])\
               .rename(['AOT_550'])

    def aerosol_this_month(date):
      """
      MODIS AOT original data product for this month (i.e. some data gaps)
      """
      # image for this month
      img =  ee.Image(\
                      ee.ImageCollection('MODIS/006/MOD08_M3')\
                        .filterDate(Atmospheric.round_month(date))\
                        .first()\
                     )
      # fill missing month (?)
      img = ee.Algorithms.If(img,\
                               # all good
                               img\
                               .select(['Aerosol_Optical_Depth_Land_Mean_Mean_550'])\
                               .divide(1000)\
                               .rename(['AOT_550']),\
                              # missing month
                                aerosol_fill(date))
      return img

    def get_AOT(AOT_band,geom):
      """
      AOT scalar value for target
      """
      return ee.Image(AOT_band).reduceRegion(reducer=ee.Reducer.mean(),\
                                 geometry=geom.centroid())\
                                .get('AOT_550')


    after_modis_start = date.difference(ee.Date('2000-03-01'),'month').gt(0)

    AOT_band = ee.Algorithms.If(after_modis_start, aerosol_this_month(date), aerosol_fill(date))

    AOT = get_AOT(AOT_band,geom)

    AOT = ee.Algorithms.If(AOT,AOT,get_AOT(aerosol_fill(date),geom))
    return AOT

# %% [markdown]
# Import required libraries

# %%
import ee
from Py6S import *
from datetime import datetime
import math
import pandas as pd
import numpy as np
import os
import sys
import folium
import ipywidgets as widgets
from IPython.display import display
from datetime import datetime, timedelta

# %% [markdown]
# **Initialize Google Earth Engine session**
#
# Need enter verification using GEE account

# %%
ee.Authenticate()
ee.Initialize(project='942205441038')

# %% [markdown]
# **Py6S function for the atmospheric correction**

# %%
# Define Py6S function
# Modified from https://github.com/ndminhhus/geeguide/blob/master/02.Atm-correction.md

def Py6S(img):
  S2 = ee.Image(img)
  date = S2.date()
  # top of atmosphere reflectance
  toa = S2.divide(10000)

  info = S2.getInfo()['properties']
  scene_date = datetime.utcfromtimestamp(info['system:time_start']/1000)# i.e. Python uses seconds, EE uses milliseconds
  solar_z = info['MEAN_SOLAR_ZENITH_ANGLE']

  h2o = Atmospheric.water(geom,date).getInfo()
  o3 = Atmospheric.ozone(geom,date).getInfo()
  aot = Atmospheric.aerosol(geom,date).getInfo()

  SRTM = ee.Image('CGIAR/SRTM90_V4')# Shuttle Radar Topography mission covers *most* of the Earth
  alt = SRTM.reduceRegion(reducer = ee.Reducer.mean(),geometry = geom.centroid()).get('elevation').getInfo()
  km = alt/1000 # i.e. Py6S uses units of kilometers

  # Instantiate
  s = SixS()

  # Atmospheric constituents
  s.atmos_profile = AtmosProfile.UserWaterAndOzone(h2o,o3)
  s.aero_profile = AeroProfile.Maritime # https://github.com/robintw/Py6S/blob/master/Py6S/Params/aeroprofile.py
  s.aot550 = aot

  # Earth-Sun-satellite geometry
  s.geometry = Geometry.User()
  s.geometry.view_z = 0               # always NADIR
  s.geometry.solar_z = solar_z        # solar zenith angle
  s.geometry.month = scene_date.month # month and day used for Earth-Sun distance
  s.geometry.day = scene_date.day     # month and day used for Earth-Sun distance
  s.altitudes.set_sensor_satellite_level()
  s.altitudes.set_target_custom_altitude(km)

  def spectralResponseFunction(bandname):
    """
    Extract spectral response function for given band name
    """
    bandSelect = {
        'B1':PredefinedWavelengths.S2A_MSI_01,
        'B2':PredefinedWavelengths.S2A_MSI_02,
        'B3':PredefinedWavelengths.S2A_MSI_03,
        'B4':PredefinedWavelengths.S2A_MSI_04,
        'B5':PredefinedWavelengths.S2A_MSI_05,
        'B6':PredefinedWavelengths.S2A_MSI_06,
        'B7':PredefinedWavelengths.S2A_MSI_07,
        'B8':PredefinedWavelengths.S2A_MSI_08,
        'B8A':PredefinedWavelengths.S2A_MSI_8A,
        'B9':PredefinedWavelengths.S2A_MSI_09,
        'B10':PredefinedWavelengths.S2A_MSI_10,
        'B11':PredefinedWavelengths.S2A_MSI_11,
        'B12':PredefinedWavelengths.S2A_MSI_12,
        }
    return Wavelength(bandSelect[bandname])

  def toa_to_rad(bandname):
    """
    Converts top of atmosphere reflectance to at-sensor radiance
    """
    # solar exoatmospheric spectral irradiance
    ESUN = info['SOLAR_IRRADIANCE_'+bandname]
    solar_angle_correction = math.cos(math.radians(solar_z))
    # Earth-Sun distance (from day of year)
    doy = scene_date.timetuple().tm_yday
    d = 1 - 0.01672 * math.cos(0.9856 * (doy-4))# http://physics.stackexchange.com/questions/177949/earth-sun-distance-on-a-given-day-of-the-year
    # conversion factor
    multiplier = ESUN*solar_angle_correction/(math.pi*d**2)
    # at-sensor radiance
    rad = toa.select(bandname).multiply(multiplier)
    return rad

  def surface_reflectance(bandname):
    """
    Calculate surface reflectance from at-sensor radiance given waveband name
    """
    # run 6S for this waveband
    s.wavelength = spectralResponseFunction(bandname)
    s.run()
    # extract 6S outputs
    Edir = s.outputs.direct_solar_irradiance             #direct solar irradiance
    Edif = s.outputs.diffuse_solar_irradiance            #diffuse solar irradiance
    Lp   = s.outputs.atmospheric_intrinsic_radiance      #path radiance
    absorb  = s.outputs.trans['global_gas'].upward       #absorption transmissivity
    scatter = s.outputs.trans['total_scattering'].upward #scattering transmissivity
    tau2 = absorb*scatter                                #total transmissivity
    # radiance to surface reflectance
    rad = toa_to_rad(bandname)
    ref = rad.subtract(Lp).multiply(math.pi).divide(tau2*(Edir+Edif))
    return ref

  # all wavebands
  output = S2.select('QA60')
  for band in ['B1','B2','B3','B4','B5','B6','B7','B8','B8A','B9','B10','B11','B12']:
    # print(band)
    output = output.addBands(surface_reflectance(band))

  return output

# %% [markdown]
# # Step 3 - Define functions required to clouds and water mask
#
# Remove cloud and cloud shadow
#
# Modified from:
# *   https://developers.google.com/earth-engine/tutorials/community/sentinel-2-s2cloudless
# *   https://github.com/ivanhykwong/marine-water-quality-time-series-hk

# %% [markdown]
# **Non-water and clouds masks**

# %%
# Funtion to add no-water mask
def add_not_water_mask(img):
    # NDWI
    ndwi = img.normalizedDifference(['B3', 'B8']).rename('NDWI')
    # mNDWI
    mndwi = img.normalizedDifference(['B3', 'B11']).rename('mNDWI')

    mndwi_water = mndwi.gt(-0.05)
    ndwi_water = ndwi.gt(0.3)

    combined_water = mndwi_water.Or(ndwi_water).rename('COMBINED_WATER')
    not_water = combined_water.Not().rename('NOT_WATER')
    return img.addBands(not_water)

# Funtion to add cloud mask
def add_cloud_bands(img):
    # Get s2cloudless image, subset the probability band.
    cld_prb = ee.Image(img.get('s2cloudless')).select('probability')
    # Condition s2cloudless by the probability threshold value (1 clouds)
    is_cloud = cld_prb.gt(CLD_PRB_THRESH).rename('clouds')
    # Add the cloud probability layer and cloud mask as image bands.
    return img.addBands(ee.Image([cld_prb, is_cloud]))

# Funtion to add cloud shadow mask
def add_shadow_bands(img):
    # Identify dark NIR pixels that are not water (potential cloud shadow pixels).
    SR_BAND_SCALE = 1e4
    dark_pixels = img.select('B8').lt(NIR_DRK_THRESH*SR_BAND_SCALE).rename('dark_pixels')

    # Determine the direction to project cloud shadow from clouds (assumes UTM projection).
    shadow_azimuth = ee.Number(90).subtract(ee.Number(img.get('MEAN_SOLAR_AZIMUTH_ANGLE')));

    # Project shadows from clouds for the distance specified by the CLD_PRJ_DIST input.
    cld_proj = (img.select('clouds').directionalDistanceTransform(shadow_azimuth, CLD_PRJ_DIST*10)
        .reproject(**{'crs': img.select(0).projection(), 'scale': 10})
        .select('distance')
        .mask()
        .rename('cloud_transform'))

    # Identify the intersection of dark pixels with cloud shadow projection.
    shadows = cld_proj.multiply(dark_pixels).rename('shadows')
    # Add dark pixels, cloud projection, and identified shadows as image bands.
    return img.addBands(ee.Image([dark_pixels, cld_proj, shadows]))

# Funtion to add combined mask
def add_cld_shdw_mask(img):

    # Add cloud component bands.
    img_cloud = add_cloud_bands(img)
    # Add cloud shadow component bands.
    img_cloud_shadow = add_shadow_bands(img_cloud)

    # Combine cloud and shadow mask, set cloud and shadow as value 1, else 0.
    is_cld_shdw = img_cloud_shadow.select('clouds').add(img_cloud_shadow.select('shadows')).gt(0)
    # Remove small cloud-shadow patches and dilate remaining pixels by BUFFER input.
    is_cld_shdw = (is_cld_shdw.focalMin(2).focalMax(BUFFER*2/10)
        .reproject(**{'crs': img.select([0]).projection(), 'scale': 10})
        .rename('cloudmask'))

    # Add final mask
    return img_cloud_shadow.addBands(is_cld_shdw)

# %% [markdown]
# **Import colecction and apply corrections**

# %%
# Function to apply corrections and add mask
def apply_corrections(image):
    # Apply Py6S corrections
    corrected_img = Py6S(image)
    print("Bands after Py6S:", corrected_img.bandNames().getInfo())
    # Add masks
    masked_img = add_not_water_mask(corrected_img)
    print("Bands after add_not_water_mask:", masked_img.bandNames().getInfo())
    final_img = add_cld_shdw_mask(masked_img)
    print("Bands after add_cld_shdw_mask:", final_img.bandNames().getInfo())
    return final_img

# %%
# Import and filter S2 and s2cloudless
def get_s2_sr_cld_col(aoi, dates, search_window=6):
    # Process each date in the provided list to find and correct images within the search window
    def process_date(date_str):
      # Calculate the search window around each target date
        target_date = datetime.strptime(date_str, '%Y-%m-%d')
        start_search = target_date - timedelta(days=search_window)
        end_search = target_date + timedelta(days=search_window)

      # Filter Sentinel-2 surface reflectance images by AOI and date, with cloud cover threshold
        s2_sr_col = ee.ImageCollection('COPERNICUS/S2_HARMONIZED')\
                     .filterBounds(aoi)\
                     .filterDate(start_search.strftime('%Y-%m-%d'), end_search.strftime('%Y-%m-%d'))\
                     .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', CLOUD_FILTER))

        # Filter s2cloudless images for the same AOI and date range
        s2_cloudless_col = ee.ImageCollection('COPERNICUS/S2_CLOUD_PROBABILITY')\
                            .filterBounds(aoi)\
                            .filterDate(start_search.strftime('%Y-%m-%d'), end_search.strftime('%Y-%m-%d'))

        # Join s2 surface reflectance and s2cloudless collections on image index
        joined_col = ee.ImageCollection(ee.Join.saveFirst('s2cloudless').apply(**{
            'primary': s2_sr_col,
            'secondary': s2_cloudless_col,
            'condition': ee.Filter.equals(**{
                'leftField': 'system:index',
                'rightField': 'system:index'
            })
        }))

        # Map over the collection to calculate the absolute difference in time from the target date
        def date_diff(image):
            image_date = ee.Date(image.get('system:time_start'))
            diff = ee.Number(target_date.timestamp() * 1000).subtract(image_date.millis()).abs()
            return image.set('dateDiff', diff)
        # Sort by time difference and select the first (closest) image
        nearest_image = joined_col.map(date_diff).sort('dateDiff').first()
        # Print selected date and cloudiness for verification
        selected_date = ee.Date(nearest_image.get('system:time_start')).format('YYYY-MM-dd')
        cloud_percentage = nearest_image.get('CLOUDY_PIXEL_PERCENTAGE').getInfo()
        print(f'Original date: {date_str}, Select date: {selected_date.getInfo()} Cloudiness: {cloud_percentage}%')

        # Apply corrections and masks to the nearest image.
        return apply_corrections(nearest_image)
    return [process_date(date) for date in dates]

# %% [markdown]
# # Step 4 - Apply functions to the area and date selected

# %% [markdown]
# **Filter by date and aoi**

# %%
# Define the area of interest (AOI)
Clip = ee.FeatureCollection('projects/epvillanueva/assets/Clip')
AOI = Clip.geometry()
geom = AOI
# Dates of in-situ information to train and test the future machine learning model
DATES = ['2022-11-24', '2023-01-27', '2023-02-05', '2023-03-17', '2023-03-27', '2023-04-11', '2023-04-26', '2023-05-16', '2023-06-05', '2023-07-05']
CLD_PRB_THRESH = 40  #	Cloud probability (%); values greater than are considered cloud
NIR_DRK_THRESH = 0.5 # Near-infrared reflectance; values less than are considered potential cloud shadow
CLD_PRJ_DIST = 2 # Maximum distance (km) to search for cloud shadows from cloud edges
BUFFER = 15 # Distance (m) to dilate the edge of cloud-identified objects
CLOUD_FILTER = 50

# %% [markdown]
# **Apply corrections and add mask to visualization**

# %%
# Apply functions to collections
collections = get_s2_sr_cld_col(AOI, DATES)
# Out:
# Original date: 2022-11-24, Select date: 2022-11-22 Cloudiness: 38.6851807335749%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Original date: 2023-01-27, Select date: 2023-01-26 Cloudiness: 0.307621597213263%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Original date: 2023-02-05, Select date: 2023-02-05 Cloudiness: 15.2280780473642%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Original date: 2023-03-17, Select date: 2023-03-17 Cloudiness: 13.6425670580218%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Original date: 2023-03-27, Select date: 2023-03-27 Cloudiness: 0.0173312245320949%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Original date: 2023-04-11, Select date: 2023-04-11 Cloudiness: 40.2592258623365%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Original date: 2023-04-26, Select date: 2023-04-26 Cloudiness: 10.3341075851036%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Original date: 2023-05-16, Select date: 2023-05-11 Cloudiness: 10.7139155770593%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Original date: 2023-06-05, Select date: 2023-06-10 Cloudiness: 4.52149322137851%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Original date: 2023-07-05, Select date: 2023-07-05 Cloudiness: 34.1797956332861%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']

# %% [markdown]
# **Visualization**

# %%
# Function to add Google Earth Engine image layers to Folium maps
def add_ee_layer(self, ee_image_object, vis_params, name, show=True, opacity=1, min_zoom=0):

    # Generate map ID and token for the Earth Engine image
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    # Add the Earth Engine tile layer to the Folium map
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
        name=name,
        show=show,
        opacity=opacity,
        min_zoom=min_zoom,
        overlay=True,
        control=True
    ).add_to(self)

# Extend the Folium Map class to include the add_ee_layer method
folium.Map.add_ee_layer = add_ee_layer

# Function to generate and add specific layers of interest to the map for a given image
def generate_layers_for_date(img, map_object):

    # Self-mask layers to visualize specific features
    clouds = img.select('clouds').selfMask()
    shadows = img.select('shadows').selfMask()
    dark_pixels = img.select('dark_pixels').selfMask()
    probability = img.select('probability').selfMask()
    cloudmask = img.select('cloudmask').selfMask()
    cloud_transform = img.select('cloud_transform').selfMask()
    not_water = img.select('NOT_WATER').selfMask()

    # Add specific layers to the map with visualization parameters
    map_object.add_ee_layer(img, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 0.25, 'gamma': 1.1}, 'S2 image')
    map_object.add_ee_layer(cloudmask, {'palette': 'orange'}, 'Cloud Mask')
    map_object.add_ee_layer(not_water, {'palette': 'blue'}, 'Not Water')
    # Uncomment to add additional layers
    # map_object.add_ee_layer(probability, {'min': 0, 'max': 100}, 'Probability (cloud)')
    # map_object.add_ee_layer(clouds, {'palette': 'e056fd'}, 'Clouds')
    # map_object.add_ee_layer(cloud_transform, {'min': 0, 'max': 1, 'palette': ['white', 'black']}, 'Cloud Transform')
    # map_object.add_ee_layer(dark_pixels, {'palette': 'orange'}, 'Dark Pixels')
    # map_object.add_ee_layer(shadows, {'palette': 'yellow'}, 'Shadows')

# Function to visualize layers with a date selector for user interaction
def display_cloud_layers_with_date_selector(collections, dates, aoi):
    def update_map(date_index):
       # Create a new map object for the selected date
        center = aoi.centroid(10).coordinates().reverse().getInfo()
        m = folium.Map(location=center, zoom_start=14)

        # Generate and add layers to the map based on the selected date
        img = collections[date_index]
        generate_layers_for_date(img, m)

        # Add layer control to toggle layers on/off
        m.add_child(folium.LayerControl())

        # Display the updated map
        display(m)

    # Create a dropdown widget for date selection
    date_selector = widgets.Dropdown(
        options=[(date, i) for i, date in enumerate(dates)],
        value=0,
        description='Select Date:',
    )

    # Link the date selector widget to the map update function
    widgets.interact(update_map, date_index=date_selector)

# %%
display_cloud_layers_with_date_selector(collections, DATES, AOI)
# Out:
# interactive(children=(Dropdown(description='Select Date:', options=(('2022-11-24', 0), ('2023-01-27', 1), ('20…

# %% [markdown]
# **Apply the masks and clip after confirming correct use with the display**

# %%
# Function to apply masks and clip
def apply_masks_and_clip(img):
    # Apply non-water, cloud, and shadow masks to the image.
    masked_img = add_cld_shdw_mask(add_not_water_mask(img))
    # print("Bands after masks:", masked_img.bandNames().getInfo())

    # Invert masks to keep only unmasked areas (0 = no clouds, no shadows, and water presence)
    cloud_shadow_mask = masked_img.select('cloudmask').Not()
    water_mask = masked_img.select('NOT_WATER').Not()

    # Combine masks to retain only unmasked areas (no clouds, no shadows, and including water)
    final_mask = cloud_shadow_mask.And(water_mask)
    # Update the image mask with the final mask and clip to the area of interest (AOI)
    final_img = masked_img.updateMask(final_mask).clip(AOI)

    # Select bands
    band_names = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
    selected_final_img = final_img.select(band_names)
    print("Bands of processed images :", selected_final_img.bandNames().getInfo())

    return selected_final_img

# Function to visualize the processed images
def visualize_processed_images(processed_collections, dates, aoi):
    def update_map(date_index):
        # Create a new map object for the selected date
        center = aoi.centroid(10).coordinates().reverse().getInfo()
        m = folium.Map(location=center, zoom_start=14)

        # Add only the processed and clipped image to the map
        img = processed_collections[date_index]
        m.add_ee_layer(img, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 0.25, 'gamma': 1.1}, 'Processed S2 image')
        # Add layer control for toggling layers on and off
        m.add_child(folium.LayerControl())

        # Display the updated map
        display(m)

    # Create a dropdown widget for selecting dates
    date_selector = widgets.Dropdown(
        options=[(date, i) for i, date in enumerate(dates)],
        value=0,
        description='Select Date:',
    )

    # Link the date selector widget to the map updating function
    widgets.interact(update_map, date_index=date_selector)

# %%
# Process images with masks and clipping
processed_collections = [apply_masks_and_clip(img) for img in collections]

# Visualize the processed images
visualize_processed_images(processed_collections, DATES, AOI)
# Out:
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# interactive(children=(Dropdown(description='Select Date:', options=(('2022-11-24', 0), ('2023-01-27', 1), ('20…

# %% [markdown]
# # Step 5 - Extract satellite data at in-situ locations
#
# After processing the date images of the in-situ data, the information of each pixel that matches in date and coordinate with the in-situ data is extracted to train and evaluate machine learning models to predict the variables of interest.

# %%
# Define the FeatureCollection of stations from a specified Earth Engine asset.
stations = ee.FeatureCollection('projects/epvillanueva10/assets/Stations')

# Function to extract data from images at station locations.
def extract_data_for_stations(processed_collections, stations):
    all_results = []

    # Retrieve a list of station IDs.
    station_ids = stations.aggregate_array('system:index').getInfo()

    for img in processed_collections:
        # Extract the image date.
        image_date = ee.Date(img.get('system:time_start')).format('YYYY-MM-dd').getInfo()

        for station_id in station_ids:
            # Get the specific station by ID.
            station = stations.filter(ee.Filter.eq('system:index', station_id)).first()
            # Retrieve station coordinates and name.
            coords = station.geometry().coordinates().getInfo()
            station_name = station.get('Estacion').getInfo()

            # Extract image values at the station coordinates.
            values = img.reduceRegion(
                ee.Reducer.toList(),
                ee.Geometry.Point(coords),
                10
            ).getInfo()

            # Prepare the results dictionary, converting empty lists to NaN.
            result = {
                'Station': station_name,
                'Date': image_date,
                'coordinates': coords
            }
            for band in values.keys():
                result[band] = values[band][0] if values[band] else float('nan')

            all_results.append(result)

    return all_results

# %%
# Apply the function to the entire collection and retrieve station data.
station_data = extract_data_for_stations(processed_collections, stations)

# %% [markdown]
# # Step 6 - Prepare satellite and in-situ data for the machine learning models

# %% [markdown]
# **Load satellite and in-situ data**

# %%
import pandas as pd
# Load satellite data from CSV file in Google Drive
satellite_data = pd.read_csv('/content/drive/MyDrive/Mallorquin/data/satellite_data.csv')
satellite_data['Date'] = pd.to_datetime(satellite_data['Date'])

# Load in-situ data from CSV file in Google Drive
in_situ_data = pd.read_csv('/content/drive/MyDrive/Mallorquin/data/insitu_data.csv')
in_situ_data['Date'] = pd.to_datetime(in_situ_data['Date'])

# Display information about the in-situ data DataFrame
in_situ_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Station      300 non-null    int64
#  1   Latitude     300 non-null    float64
#  2   Longitude    300 non-null    float64
#  3   Date         300 non-null    datetime64[ns]
#  4   Temperature  252 non-null    float64
#  5   Salinity     240 non-null    float64
#  6   CSS          217 non-null    float64
#  7   DO           192 non-null    float64
#  8   Chl_a        12 non-null     float64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 21.2 KB

# %% [markdown]
# **Adjust the dates to combine the in situ data with the satellite data**

# %%
# Unique dates in satellite data
unique_satellite_dates = satellite_data['Date'].unique()
print(unique_satellite_dates)
# Out:
# ['2022-11-22T00:00:00.000000000' '2023-01-26T00:00:00.000000000'
#  '2023-02-05T00:00:00.000000000' '2023-03-17T00:00:00.000000000'
#  '2023-03-27T00:00:00.000000000' '2023-04-11T00:00:00.000000000'
#  '2023-04-26T00:00:00.000000000' '2023-05-11T00:00:00.000000000'
#  '2023-06-10T00:00:00.000000000' '2023-07-05T00:00:00.000000000']

# %%
# Unique dates in in-situ data
unique_in_situ_dates = in_situ_data['Date'].unique()
print(unique_in_situ_dates)
# Out:
# ['2022-11-22T00:00:00.000000000' '2023-01-26T00:00:00.000000000'
#  '2023-02-05T00:00:00.000000000' '2023-03-17T00:00:00.000000000'
#  '2023-03-27T00:00:00.000000000' '2023-04-11T00:00:00.000000000'
#  '2023-04-26T00:00:00.000000000' '2023-05-16T00:00:00.000000000'
#  '2023-06-05T00:00:00.000000000' '2023-07-05T00:00:00.000000000']

# %%
# Copy the in situ data to adjust the dates to combine the in situ with the satellite data for the closest dates
adjusted_in_situ = in_situ_data.copy()
adjusted_in_situ.loc[adjusted_in_situ['Date'] == '2022-11-24', 'Date'] = pd.to_datetime('2022-11-22')
adjusted_in_situ.loc[adjusted_in_situ['Date'] == '2023-01-27', 'Date'] = pd.to_datetime('2023-01-26')
adjusted_in_situ.loc[adjusted_in_situ['Date'] == '2023-02-03', 'Date'] = pd.to_datetime('2023-02-05')
adjusted_in_situ.loc[adjusted_in_situ['Date'] == '2023-05-16', 'Date'] = pd.to_datetime('2023-05-11')
adjusted_in_situ.loc[adjusted_in_situ['Date'] == '2023-06-05', 'Date'] = pd.to_datetime('2023-06-10')

# Merge in-situ data with satellite data based on 'Station' and 'Date' columns
combined_data = pd.merge(adjusted_in_situ, satellite_data, on=['Station', 'Date'], how='inner')
# Drop columns that are duplicated in both or don't have surface information
combined_data.drop(['coordinates', 'Station', 'Latitude', 'Longitude', 'Date', 'B10', 'DO'], axis=1, inplace=True)

# Adjust the scale of reflectance values by multiplying each band by 10000
# This converts the reflectance back to the original scale used before atmospheric correction
bands = ['B' + str(b) for b in [1, 2, 3, 4, 5, 6, 7, 8, '8A', 9, 11, 12]]
combined_data[bands] = (combined_data[bands]*10000)

# Display the first few rows of the combined data
combined_data.head()
# Out:
#    Temperature   Salinity   CSS  Chl_a          B1         B11        B12  \
# 0    30.721048  28.544563  0.92    NaN         NaN         NaN        NaN
# 1    29.548711  29.775934  0.70    NaN         NaN         NaN        NaN
# 2    29.436773  29.791698  1.14    NaN  916.052976  491.008186  458.16432
# 3    29.168811  28.516698  0.87    NaN         NaN         NaN        NaN
# 4    29.063744  29.880780  1.58    NaN         NaN         NaN        NaN
#
#            B2          B3         B4          B5          B6          B7  \
# 0         NaN         NaN        NaN         NaN         NaN         NaN
# 1         NaN         NaN        NaN         NaN         NaN         NaN
# 2  961.593349  980.985059  816.02325  782.316097  724.203465  771.352872
# 3         NaN         NaN        NaN         NaN         NaN         NaN
# 4         NaN         NaN        NaN         NaN         NaN         NaN
#
#            B8         B8A           B9
# 0         NaN         NaN          NaN
# 1         NaN         NaN          NaN
# 2  715.700342  664.457103  2858.698686
# 3         NaN         NaN          NaN
# 4         NaN         NaN          NaN

# %% [markdown]
# The observed NaN values represent the absence of in-situ data for some dates and/or stations, and the absence of satellite data due to the masks applied.

# %% [markdown]
# **Save .csv files with the data of each variable in Google Drive for machine learning models**

# %%
# Drop specified columns from the Salinity
salinity = combined_data.drop(['CSS', 'Temperature', 'Chl_a'], axis=1)
# Remove rows with missing values
salinity.dropna(inplace=True)
# Save the DataFrame to CSV
salinity.to_csv('/content/drive/My Drive/Mallorquin/data/Salinity.csv', index=False)

# Drop specified columns from the Temperature
temperature = combined_data.drop(['Salinity', 'CSS', 'Chl_a'], axis=1)
# Remove rows with missing values
temperature.dropna(inplace=True)
# Save the DataFrame to CSV
temperature.to_csv('/content/drive/My Drive/Mallorquin/data/Temperature.csv', index=False)

# Drop specified columns from the CSS
css = combined_data.drop(['Salinity', 'Temperature', 'Chl_a'], axis=1)
# Remove rows with missing values
css.dropna(inplace=True)
# Save the DataFrame to CSV
css.to_csv('/content/drive/My Drive/Mallorquin/data/CSS.csv', index=False)

# Drop specified columns from the Chl_a
chl = combined_data.drop(['Salinity', 'CSS', 'Temperature'], axis=1)
# Remove rows with missing values
chl.dropna(inplace=True)
# Save the DataFrame to CSV
chl.to_csv('/content/drive/My Drive/Mallorquin/data/Chl_a.csv', index=False)

# %% [markdown]
# # Step 7 - Apply correction and mask functions to entire collection for export

# %% [markdown]
# The correction and masking functions already established will be used on a selection of images from the collection. One image will be chosen for each month, the one with the lowest percentage of cloudiness.
#
# To obtain these images, the function "get_s2_sr_cld_col" will be updated to the function "get_least_cloudy_image_per_month".

# %%
# Function to retrieve the least cloudy image for each month within a specified date range for a given area of interest (AOI).
def get_least_cloudy_image_per_month(start_date, end_date, aoi):
    # Generate a range of dates from start to end with one-month intervals.
    date_range = pd.date_range(start_date, end_date, freq='MS')
    selected_images = []  # To store selected images.
    image_dates = []  # To store the dates of selected images.

    # Iterate through each month in the date range.
    for date in date_range:
        # Define the start and end of the month.
        start_month = date.strftime('%Y-%m-%d')
        end_month = (date + pd.offsets.MonthEnd()).strftime('%Y-%m-%d')

        # Filter Sentinel-2 surface reflectance images by AOI and date, sorting by cloud coverage.
        s2_sr_col = (ee.ImageCollection('COPERNICUS/S2_HARMONIZED')
                      .filterBounds(aoi)
                      .filterDate(start_month, end_month)
                      .sort('CLOUDY_PIXEL_PERCENTAGE'))

        # Filter corresponding cloud probability images for the same AOI and date range.
        s2_cloudless_col = (ee.ImageCollection('COPERNICUS/S2_CLOUD_PROBABILITY')
                             .filterBounds(aoi)
                             .filterDate(start_month, end_month))

        # Join the surface reflectance and cloud probability collections using image indices.
        joined_col = ee.ImageCollection(ee.Join.saveFirst('s2cloudless').apply(
            primary=s2_sr_col,
            secondary=s2_cloudless_col,
            condition=ee.Filter.equals(
                leftField='system:index',
                rightField='system:index'
            )))

        # Check if there are any images for the month.
        count = joined_col.size().getInfo()
        if count > 0:
            least_cloudy_image = joined_col.first()

            # Extract and print date and cloudiness information.
            date_info = least_cloudy_image.date().format('YYYY-MM-dd').getInfo()
            cloud_info = least_cloudy_image.get('CLOUDY_PIXEL_PERCENTAGE').getInfo()
            print(f'Date: {date_info}, Cloudiness Percentage: {cloud_info}%')


            # Apply corrections (e.g., atmospheric corrections, masks) to the image and add to the list.
            corrected_image = Py6S(least_cloudy_image)
            final_image = apply_masks_and_clip(corrected_image)

            selected_images.append(final_image)
            image_dates.append(date_info)
        else:
            print(f"No images available for the month: {start_month}")

    return selected_images, image_dates

# %%
# Apply functions to collections
collections_per_month, image_dates = get_least_cloudy_image_per_month('2016-01-01', '2023-12-31', AOI)
# Out:
# Date: 2016-01-23, Cloudiness Percentage: 0.4917%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# No images available for the month: 2016-02-01
# Date: 2016-03-23, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2016-04-22, Cloudiness Percentage: 88.2421%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2016-05-22, Cloudiness Percentage: 0.5854%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2016-06-11, Cloudiness Percentage: 6.2439%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2016-07-21, Cloudiness Percentage: 19.198%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2016-08-30, Cloudiness Percentage: 22.4063%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2016-09-19, Cloudiness Percentage: 4.3%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2016-10-29, Cloudiness Percentage: 28.3734%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2016-11-08, Cloudiness Percentage: 11.4861%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2016-12-18, Cloudiness Percentage: 2.3287%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2017-01-27, Cloudiness Percentage: 0.6465%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2017-02-26, Cloudiness Percentage: 0.2241%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2017-03-18, Cloudiness Percentage: 1.7595%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2017-04-07, Cloudiness Percentage: 37.2122%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2017-05-17, Cloudiness Percentage: 3.8411%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2017-06-06, Cloudiness Percentage: 8.1611%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2017-07-16, Cloudiness Percentage: 79.9751%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2017-08-25, Cloudiness Percentage: 7.3002%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2017-09-14, Cloudiness Percentage: 93.486%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2017-10-19, Cloudiness Percentage: 83.8106%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2017-11-18, Cloudiness Percentage: 42.0977%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2017-12-23, Cloudiness Percentage: 0.0115%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2018-01-27, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2018-02-01, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2018-03-28, Cloudiness Percentage: 0.5035%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2018-04-22, Cloudiness Percentage: 15.5307%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2018-05-12, Cloudiness Percentage: 42.0084%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2018-06-16, Cloudiness Percentage: 0.0131%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2018-07-21, Cloudiness Percentage: 13.0133%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2018-08-20, Cloudiness Percentage: 0.2204%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2018-09-09, Cloudiness Percentage: 4.3752%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2018-10-24, Cloudiness Percentage: 36.4747%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2018-11-23, Cloudiness Percentage: 0.2406%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2018-12-23, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2019-01-02, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2019-02-06, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2019-03-08, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2019-04-07, Cloudiness Percentage: 0.558%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2019-05-22, Cloudiness Percentage: 1.3472%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2019-06-26, Cloudiness Percentage: 0.0272%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2019-07-21, Cloudiness Percentage: 2.1577%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2019-08-10, Cloudiness Percentage: 0.2511%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2019-09-09, Cloudiness Percentage: 0.6469%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2019-10-04, Cloudiness Percentage: 21.7762%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2019-11-18, Cloudiness Percentage: 1.5486%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2019-12-13, Cloudiness Percentage: 2.8671%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2020-01-12, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2020-02-06, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2020-03-02, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2020-04-26, Cloudiness Percentage: 0.0346%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2020-05-21, Cloudiness Percentage: 4.3129%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2020-06-25, Cloudiness Percentage: 0.9482%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2020-07-15, Cloudiness Percentage: 0.2338%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2020-08-04, Cloudiness Percentage: 8.1339%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2020-09-23, Cloudiness Percentage: 5.673%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2020-10-28, Cloudiness Percentage: 5.5026%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2020-11-27, Cloudiness Percentage: 16.1805%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2020-12-27, Cloudiness Percentage: 0.3335%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2021-01-16, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2021-02-25, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2021-03-02, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2021-04-21, Cloudiness Percentage: 0.7319%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2021-05-21, Cloudiness Percentage: 0.1277%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2021-06-20, Cloudiness Percentage: 1.1986%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2021-07-20, Cloudiness Percentage: 0.343%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2021-08-29, Cloudiness Percentage: 2.6555%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2021-09-18, Cloudiness Percentage: 59.8132%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2021-10-08, Cloudiness Percentage: 10.8944%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2021-11-12, Cloudiness Percentage: 0.1532%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2021-12-07, Cloudiness Percentage: 0.0132%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2022-01-06, Cloudiness Percentage: 0.0682%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2022-02-25, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2022-03-22, Cloudiness Percentage: 0.0716064646640861%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2022-04-06, Cloudiness Percentage: 8.31216503185357%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2022-05-21, Cloudiness Percentage: 4.74599925774314%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2022-06-20, Cloudiness Percentage: 72.1677805969841%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2022-07-15, Cloudiness Percentage: 0.192149809948019%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2022-08-19, Cloudiness Percentage: 0.238758558431512%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2022-09-08, Cloudiness Percentage: 27.1133059459994%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2022-10-28, Cloudiness Percentage: 1.97368553267001%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2022-11-27, Cloudiness Percentage: 23.7657159917091%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2022-12-27, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2023-01-06, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2023-02-10, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2023-03-22, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2023-04-01, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2023-05-11, Cloudiness Percentage: 10.7139155770593%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2023-06-20, Cloudiness Percentage: 0.0225326036092857%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2023-07-20, Cloudiness Percentage: 0%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2023-08-04, Cloudiness Percentage: 0.338447630511074%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2023-09-28, Cloudiness Percentage: 2.31422048341065%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2023-10-13, Cloudiness Percentage: 1.72792068287632%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2023-11-27, Cloudiness Percentage: 1.49696858386752%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Date: 2023-12-02, Cloudiness Percentage: 2.97345333162657%
# Bands after Py6S: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Bands after add_not_water_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER']
# Bands after add_cld_shdw_mask: ['QA60', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12', 'NOT_WATER', 'probability', 'clouds', 'dark_pixels', 'cloud_transform', 'shadows', 'cloudmask']
# Bands of processed images : ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']

# %%
# Function to export the collection to a GEE asset collection
def export_to_ee_collection(image_collection, image_dates, aoi):

    for img, date in zip(image_collection, image_dates):
        asset_id = f"{'projects/epvillanueva10/assets/Mallorquin'}/{date}"

        # Define the export parameters
        export_task = ee.batch.Export.image.toAsset(
            image=img.toFloat(),
            description=date,
            assetId=asset_id,
            region=aoi,
            scale=20,
            maxPixels=1e13
        )

        # Start the export task
        export_task.start()
        print(f'Exporting image {date} to {asset_id}')

export_to_ee_collection(collections_per_month, image_dates, AOI)
# Out:
# Exporting image 2016-01-23 to projects/epvillanueva10/assets/Mallorquin/2016-01-23
# Exporting image 2016-03-23 to projects/epvillanueva10/assets/Mallorquin/2016-03-23
# Exporting image 2016-04-22 to projects/epvillanueva10/assets/Mallorquin/2016-04-22
# Exporting image 2016-05-22 to projects/epvillanueva10/assets/Mallorquin/2016-05-22
# Exporting image 2016-06-11 to projects/epvillanueva10/assets/Mallorquin/2016-06-11
# Exporting image 2016-07-21 to projects/epvillanueva10/assets/Mallorquin/2016-07-21
# Exporting image 2016-08-30 to projects/epvillanueva10/assets/Mallorquin/2016-08-30
# Exporting image 2016-09-19 to projects/epvillanueva10/assets/Mallorquin/2016-09-19
# Exporting image 2016-10-29 to projects/epvillanueva10/assets/Mallorquin/2016-10-29
# Exporting image 2016-11-08 to projects/epvillanueva10/assets/Mallorquin/2016-11-08
# Exporting image 2016-12-18 to projects/epvillanueva10/assets/Mallorquin/2016-12-18
# Exporting image 2017-01-27 to projects/epvillanueva10/assets/Mallorquin/2017-01-27
# Exporting image 2017-02-26 to projects/epvillanueva10/assets/Mallorquin/2017-02-26
# Exporting image 2017-03-18 to projects/epvillanueva10/assets/Mallorquin/2017-03-18
# Exporting image 2017-04-07 to projects/epvillanueva10/assets/Mallorquin/2017-04-07
# Exporting image 2017-05-17 to projects/epvillanueva10/assets/Mallorquin/2017-05-17
# Exporting image 2017-06-06 to projects/epvillanueva10/assets/Mallorquin/2017-06-06
# Exporting image 2017-07-16 to projects/epvillanueva10/assets/Mallorquin/2017-07-16
# Exporting image 2017-08-25 to projects/epvillanueva10/assets/Mallorquin/2017-08-25
# Exporting image 2017-09-14 to projects/epvillanueva10/assets/Mallorquin/2017-09-14
# Exporting image 2017-10-19 to projects/epvillanueva10/assets/Mallorquin/2017-10-19
# Exporting image 2017-11-18 to projects/epvillanueva10/assets/Mallorquin/2017-11-18
# Exporting image 2017-12-23 to projects/epvillanueva10/assets/Mallorquin/2017-12-23
# Exporting image 2018-01-27 to projects/epvillanueva10/assets/Mallorquin/2018-01-27
# Exporting image 2018-02-01 to projects/epvillanueva10/assets/Mallorquin/2018-02-01
# Exporting image 2018-03-28 to projects/epvillanueva10/assets/Mallorquin/2018-03-28
# Exporting image 2018-04-22 to projects/epvillanueva10/assets/Mallorquin/2018-04-22
# Exporting image 2018-05-12 to projects/epvillanueva10/assets/Mallorquin/2018-05-12
# Exporting image 2018-06-16 to projects/epvillanueva10/assets/Mallorquin/2018-06-16
# Exporting image 2018-07-21 to projects/epvillanueva10/assets/Mallorquin/2018-07-21
# Exporting image 2018-08-20 to projects/epvillanueva10/assets/Mallorquin/2018-08-20
# Exporting image 2018-09-09 to projects/epvillanueva10/assets/Mallorquin/2018-09-09
# Exporting image 2018-10-24 to projects/epvillanueva10/assets/Mallorquin/2018-10-24
# Exporting image 2018-11-23 to projects/epvillanueva10/assets/Mallorquin/2018-11-23
# Exporting image 2018-12-23 to projects/epvillanueva10/assets/Mallorquin/2018-12-23
# Exporting image 2019-01-02 to projects/epvillanueva10/assets/Mallorquin/2019-01-02
# Exporting image 2019-02-06 to projects/epvillanueva10/assets/Mallorquin/2019-02-06
# Exporting image 2019-03-08 to projects/epvillanueva10/assets/Mallorquin/2019-03-08
# Exporting image 2019-04-07 to projects/epvillanueva10/assets/Mallorquin/2019-04-07
# Exporting image 2019-05-22 to projects/epvillanueva10/assets/Mallorquin/2019-05-22
# Exporting image 2019-06-26 to projects/epvillanueva10/assets/Mallorquin/2019-06-26
# Exporting image 2019-07-21 to projects/epvillanueva10/assets/Mallorquin/2019-07-21
# Exporting image 2019-08-10 to projects/epvillanueva10/assets/Mallorquin/2019-08-10
# Exporting image 2019-09-09 to projects/epvillanueva10/assets/Mallorquin/2019-09-09
# Exporting image 2019-10-04 to projects/epvillanueva10/assets/Mallorquin/2019-10-04
# Exporting image 2019-11-18 to projects/epvillanueva10/assets/Mallorquin/2019-11-18
# Exporting image 2019-12-13 to projects/epvillanueva10/assets/Mallorquin/2019-12-13
# Exporting image 2020-01-12 to projects/epvillanueva10/assets/Mallorquin/2020-01-12
# Exporting image 2020-02-06 to projects/epvillanueva10/assets/Mallorquin/2020-02-06
# Exporting image 2020-03-02 to projects/epvillanueva10/assets/Mallorquin/2020-03-02
# Exporting image 2020-04-26 to projects/epvillanueva10/assets/Mallorquin/2020-04-26
# Exporting image 2020-05-21 to projects/epvillanueva10/assets/Mallorquin/2020-05-21
# Exporting image 2020-06-25 to projects/epvillanueva10/assets/Mallorquin/2020-06-25
# Exporting image 2020-07-15 to projects/epvillanueva10/assets/Mallorquin/2020-07-15
# Exporting image 2020-08-04 to projects/epvillanueva10/assets/Mallorquin/2020-08-04
# Exporting image 2020-09-23 to projects/epvillanueva10/assets/Mallorquin/2020-09-23
# Exporting image 2020-10-28 to projects/epvillanueva10/assets/Mallorquin/2020-10-28
# Exporting image 2020-11-27 to projects/epvillanueva10/assets/Mallorquin/2020-11-27
# Exporting image 2020-12-27 to projects/epvillanueva10/assets/Mallorquin/2020-12-27
# Exporting image 2021-01-16 to projects/epvillanueva10/assets/Mallorquin/2021-01-16
# Exporting image 2021-02-25 to projects/epvillanueva10/assets/Mallorquin/2021-02-25
# Exporting image 2021-03-02 to projects/epvillanueva10/assets/Mallorquin/2021-03-02
# Exporting image 2021-04-21 to projects/epvillanueva10/assets/Mallorquin/2021-04-21
# Exporting image 2021-05-21 to projects/epvillanueva10/assets/Mallorquin/2021-05-21
# Exporting image 2021-06-20 to projects/epvillanueva10/assets/Mallorquin/2021-06-20
# Exporting image 2021-07-20 to projects/epvillanueva10/assets/Mallorquin/2021-07-20
# Exporting image 2021-08-29 to projects/epvillanueva10/assets/Mallorquin/2021-08-29
# Exporting image 2021-09-18 to projects/epvillanueva10/assets/Mallorquin/2021-09-18
# Exporting image 2021-10-08 to projects/epvillanueva10/assets/Mallorquin/2021-10-08
# Exporting image 2021-11-12 to projects/epvillanueva10/assets/Mallorquin/2021-11-12
# Exporting image 2021-12-07 to projects/epvillanueva10/assets/Mallorquin/2021-12-07
# Exporting image 2022-01-06 to projects/epvillanueva10/assets/Mallorquin/2022-01-06
# Exporting image 2022-02-25 to projects/epvillanueva10/assets/Mallorquin/2022-02-25
# Exporting image 2022-03-22 to projects/epvillanueva10/assets/Mallorquin/2022-03-22
# Exporting image 2022-04-06 to projects/epvillanueva10/assets/Mallorquin/2022-04-06
# Exporting image 2022-05-21 to projects/epvillanueva10/assets/Mallorquin/2022-05-21
# Exporting image 2022-06-20 to projects/epvillanueva10/assets/Mallorquin/2022-06-20
# Exporting image 2022-07-15 to projects/epvillanueva10/assets/Mallorquin/2022-07-15
# Exporting image 2022-08-19 to projects/epvillanueva10/assets/Mallorquin/2022-08-19
# Exporting image 2022-09-08 to projects/epvillanueva10/assets/Mallorquin/2022-09-08
# Exporting image 2022-10-28 to projects/epvillanueva10/assets/Mallorquin/2022-10-28
# Exporting image 2022-11-27 to projects/epvillanueva10/assets/Mallorquin/2022-11-27
# Exporting image 2022-12-27 to projects/epvillanueva10/assets/Mallorquin/2022-12-27
# Exporting image 2023-01-06 to projects/epvillanueva10/assets/Mallorquin/2023-01-06
# Exporting image 2023-02-10 to projects/epvillanueva10/assets/Mallorquin/2023-02-10
# Exporting image 2023-03-22 to projects/epvillanueva10/assets/Mallorquin/2023-03-22
# Exporting image 2023-04-01 to projects/epvillanueva10/assets/Mallorquin/2023-04-01
# Exporting image 2023-05-11 to projects/epvillanueva10/assets/Mallorquin/2023-05-11
# Exporting image 2023-06-20 to projects/epvillanueva10/assets/Mallorquin/2023-06-20
# Exporting image 2023-07-20 to projects/epvillanueva10/assets/Mallorquin/2023-07-20
# Exporting image 2023-08-04 to projects/epvillanueva10/assets/Mallorquin/2023-08-04
# Exporting image 2023-09-28 to projects/epvillanueva10/assets/Mallorquin/2023-09-28
# Exporting image 2023-10-13 to projects/epvillanueva10/assets/Mallorquin/2023-10-13
# Exporting image 2023-11-27 to projects/epvillanueva10/assets/Mallorquin/2023-11-27
# Exporting image 2023-12-02 to projects/epvillanueva10/assets/Mallorquin/2023-12-02
